# %% [markdown]
# # My Final Project Notebook

# %% [markdown]
# ## Introduction
# This notebook explores various aspects of data science and coding exercises.

# %% [markdown]
# ## Data Science Languages
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ## Data Science Libraries
# 1. Pandas
# 2. NumPy
# 3. Scikit-learn

# %% [markdown]
# ## Data Science Tools
# | Tool          | Purpose                 |
# |---------------|-------------------------|
# | Jupyter       | Interactive computing  |
# | Tableau       | Data visualization      |
# | TensorFlow    | Machine learning        |

# %%
# Multiplication and addition
multiply = 5 * 10
add = 20 + 30

multiply, add
# Out:
# (50, 50)

# %%
# Conversion of minutes to hours
minutes = 180
hours = minutes / 60

hours
# Out:
# 3.0

# %% [markdown]
# ## Objectives
# 1. Demonstrated proficiency in Markdown.
# 2. Showcase my basic coding skills in Python.
# 3. Exploring data science concepts that we learnt.

# %% [markdown]
# ## Author
# Kahaan Darji

# %% [markdown]
# # Screenshot
# ![python%20task%201%20ibm.png](attachment:python%20task%201%20ibm.png)
